# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
my_look_x = np.linspace(0, 10, 15)
my_look_y = 5 + np.sin(my_look_x) * 1.5

# %%
her_reaction_x = np.linspace(0, 10, 15)
her_reaction_y = 5 + np.cos(her_reaction_x) * 1.2

# %%
plt.figure(figsize=(8,6))
plt.scatter(my_look_x, my_look_y,
            c='gold', s=120, label="My gaze (first sight)", alpha=0.8)

# %%
plt.scatter(her_reaction_x,
            her_reaction_y,
                        c='violet', s=120,
            label="Her eyes' reflection", alpha=0.7,
            edgecolors='black')

# %%
plt.figure(figsize=(8,6))
plt.scatter(my_look_x, my_look_y,
            c='gold', s=120, label="My gaze (first sight)", alpha=0.8)
plt.scatter(her_reaction_x,
            her_reaction_y,
                        c='violet', s=120,
            label="Her eyes' reflection", alpha=0.7,
            edgecolors='black')
for i in range(len(your_look_x)):
    plt.plot([my_look_x[i],
her_reaction_x[i]],
             [my_look_y[i],
her_reaction_y[i]],
             color='pink', alpha=0.4,
             linestyle='--')

plt.title("Eye Contact Cluster - The First Sight Connection", fontsize=14, pad=20)
plt.xlabel("Intensity of my gaze >")
plt.ylabel("Depth of her eyes >")
plt.legend()
plt.grid(True, linestyle='--',
         alpha=0.3)
plt.show()
